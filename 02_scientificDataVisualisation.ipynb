# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# based in the data visualisation tutorial
#
# http://www.labri.fr/perso/nrougier/teaching/matplotlib/matplotlib.html
#
# https://github.com/rougier/ASPP-2016
#
# http://www.datavizcatalogue.com/methods/density_plot.html
#
# http://selection.datavisualization.ch/
#
# Fred's ImageMagick script, F. Weinhaus, 2016.

# %%
X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)

fig = plt.figure()

# %%
# Create a new figure of size 8x6 points, using 100 dots per inch
fig, ax = plt.subplots(1,1, figsize=(8,6), dpi=80)

# Create a new subplot from a grid of 1x1
ax.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
# Plot sine using green color with a continuous line of width 1 (pixels)
ax.plot(X, S, color="r", linewidth=2.5, linestyle="-", label="sine")

# Set x limits
ax.set_xlim(X.min()*1.1, X.max()*1.1)
# Set x ticks
ax.set_xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
ax.set_xticklabels([r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])


# Set y limits
ax.set_ylim(C.min()*1.1, C.max()*1.1)
# Set y ticks
ax.set_yticks([-1, 0, +1])
ax.set_yticklabels([r'$-1$', r'$0$', r'$+1$'])

# Spines
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
# Save figure using 72 dots per inch
# savefig("../figures/exercice_2.png",dpi=72)

plt.legend(loc='upper left', frameon=False)


# Add annotations to interesting points
t = 2*np.pi/3
plt.plot([t,t],[0,np.cos(t)], color ='blue', linewidth=1.5, linestyle="--")
plt.scatter([t,],[np.cos(t),], 50, color ='blue')

plt.annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)), xycoords='data',
             xytext=(+10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t,t],[0,np.sin(t)], color ='red', linewidth=1.5, linestyle="--")
plt.scatter([t,],[np.sin(t),], 50, color ='red')

plt.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)), xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

# Show bigger, translucent, ticks over lines
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(16)
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.65 ))

# Show result on screen
plt.show()

# %% [markdown]
# ## Exercise 1: Too much ink...
#
# Consider the following figure and, using matplotlib, try to remove as much ink as you can while keeping the most relevant information.

# %%
np.random.seed(123)

def gaussian(x, a, x0, sigma):
    return a*np.exp(-(x-x0)**2/(2*sigma**2))

# Clean data
X = np.linspace(15, 21, 100)
Y = gaussian(X, 0.65, 17.6, 1.)

# Noisy data
Xn = np.random.uniform(16, 20, 25)
Yn = gaussian(Xn, 0.65, 17.6, 1.) + 0.01 * np.random.normal(size=len(Xn))

plt.scatter(Xn, Yn, s=100, marker='x')
plt.plot(X, Y, 'r', alpha=0.7)

ax = plt.gca()
plt.ylim([0, 0.7])
plt.xlim([15, 21])

plt.grid(True, color='grey', linestyle='-', alpha=0.3)

ax.tick_params(axis='both', which='major', reset=True, length = 8)

plt.minorticks_on()
ax.tick_params(axis='both', which='minor', reset=True, length = 3)

# %% [markdown]
# ## Exercise 2: Using the right tool
#
# You have a nice image and you would like to show labeled detailed sub-images alongside the main image (see below). What could be the easiest way to do that ? Be careful with the labels, they must be visible independently of the images color/contrast.

# %%
A=plt.imread('images/neurons.jpg')

plt.subplot(2,2,1)
plt.xticks([])
plt.yticks([])
plt.imshow(A)

plt.axes([0.1,0.1,.8,.8])
plt.xticks([])
plt.yticks([])
plt.text(0.6,0.6, 'axes([0.1,0.1,.8,.8])',ha='center',va='center',size=20,alpha=.5)

plt.subplot(2,2,2)
plt.xticks([])
plt.yticks([])
#plt.imshow(A[])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %% [markdown]
# ## Exercise 5: Replication
#
# Look at Drawing a brain with Bokeh and try to replicate the final figure using matpltolib.
#
# or
#
# Pick one of your favorite graphic from the litterature and try to replicate it using matplotlib (and fake data).
